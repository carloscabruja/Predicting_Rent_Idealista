# %% [markdown]
# # Hyperparameter Tuning
# In this notebook, we will tune the hyperparameters of our model to find the best model for our data.

# %%
# Libraries
import pickle
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import optuna

from scipy.special import inv_boxcox, boxcox
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

# Configurations
pd.set_option('display.max_columns', None)
sns.set_style('whitegrid')
warnings.filterwarnings('ignore')

# Load data
df = pd.read_csv('../data/processed/rent_valencia.csv', index_col=0)
df.head()
# Out:
#                price  numPhotos  floor  rooms  bathrooms   size  \
# propertyCode
# 97942302       850.0         23      0      5          2  140.0
# 97956954       900.0         18      1      3          3  100.0
# 98200619      1200.0         26      2      3          2  145.0
# 98015046      1800.0         21      0      3          2  103.0
# 97530419       850.0         27      5      3          1   76.0
#
#               parkingSpacePrice  exterior  renew  new_development  \
# propertyCode
# 97942302                    0.0     False  False            False
# 97956954                    0.0      True  False            False
# 98200619                    0.0      True  False            False
# 98015046                    0.0      True  False            False
# 97530419                    0.0     False  False            False
#
#               hasParkingSpace  isParkingSpaceIncludedInPrice  isFinished  \
# propertyCode
# 97942302                False                          False        True
# 97956954                 True                           True        True
# 98200619                False                          False        True
# 98015046                False                          False        True
# 97530419                False                          False        True
#
#               hasLift  hasPlan  has360  has3DTour  hasVideo  propertyType  \
# propertyCode
# 97942302        False    False   False      False     False  countryHouse
# 97956954         True    False   False      False     False        duplex
# 98200619         True    False   False      False     False          flat
# 98015046         True    False   False      False      True          flat
# 97530419         True    False   False      False      True          flat
#
#               cluster
# propertyCode
# 97942302            3
# 97956954            0
# 98200619            0
# 98015046            0
# 97530419            0

# %%
# Transform cluster to categorical
df['cluster'] = df['cluster'].map({0: 'central', 1: 'south', 2: 'north', 3: 'west'})

# Function to Box-Cox transform a column
def box_cox_transform(column, lamda= None):
    if lamda is None:
        column, lamda = stats.boxcox(column)
        
        return column, lamda
    else:
        column = boxcox(column, lamda)
        return column

def inv_box_cox_transform(column, lamda):
    column = inv_boxcox(column, lamda)
    return column

# %%
X = df.drop(['price'], axis=1)
y = df['price']

X_train, X_test, y_train, y_test, train_index, test_index = train_test_split(X, y, df.index, test_size=0.2, random_state=42)

num_col = X_train.select_dtypes(include=['int64', 'float64']).columns
cat_col = X_train.select_dtypes(include=['object']).columns
bool_features = X_train.select_dtypes(include=['bool']).columns

preprocessor = ColumnTransformer(
    [
    ('scaler', StandardScaler(), num_col),
    ('onehot', OneHotEncoder(), cat_col)
    ],
    remainder='passthrough'
)

X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)
y_train, lamda = box_cox_transform(y_train)
y_test = box_cox_transform(y_test, lamda)

encoded_cat = preprocessor.named_transformers_['onehot'].get_feature_names_out(cat_col)
labels = np.concatenate([num_col, encoded_cat, bool_features])
df_train = pd.DataFrame(X_train, columns=labels, index=train_index)
df_test = pd.DataFrame(X_test, columns=labels, index=test_index)
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3334 entries, 97840274 to 97951630
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   numPhotos                      3334 non-null   float64
#  1   floor                          3334 non-null   float64
#  2   rooms                          3334 non-null   float64
#  3   bathrooms                      3334 non-null   float64
#  4   size                           3334 non-null   float64
#  5   parkingSpacePrice              3334 non-null   float64
#  6   propertyType_chalet            3334 non-null   float64
#  7   propertyType_countryHouse      3334 non-null   float64
#  8   propertyType_duplex            3334 non-null   float64
#  9   propertyType_flat              3334 non-null   float64
#  10  propertyType_penthouse         3334 non-null   float64
#  11  propertyType_studio            3334 non-null   float64
#  12  cluster_central                3334 non-null   float64
#  13  cluster_north                  3334 non-null   float64
#  14  cluster_south                  3334 non-null   float64
#  15  cluster_west                   3334 non-null   float64
#  16  exterior                       3334 non-null   float64
#  17  renew                          3334 non-null   float64
#  18  new_development                3334 non-null   float64
#  19  hasParkingSpace                3334 non-null   float64
#  20  isParkingSpaceIncludedInPrice  3334 non-null   float64
#  21  isFinished                     3334 non-null   float64
#  22  hasLift                        3334 non-null   float64
#  23  hasPlan                        3334 non-null   float64
#  24  has360                         3334 non-null   float64
#  25  has3DTour                      3334 non-null   float64
#  26  hasVideo                       3334 non-null   float64
# dtypes: float64(27)
# memory usage: 729.3 KB

# %% [markdown]
# ### Random Forest

# %%
def rf_objetive(trial):
    criterion = trial.suggest_categorical('criterion', ['squared_error', 'absolute_error'])
    bootstrap = trial.suggest_categorical('bootstrap',['True','False'])
    max_depth = trial.suggest_int('max_depth', 1, 10000)
    max_features = trial.suggest_categorical('max_features', ['auto', 'sqrt', 'log2'])
    max_leaf_nodes = trial.suggest_int('max_leaf_nodes', 1, 10000)
    n_estimators =  trial.suggest_int('n_estimators', 30, 1000)
    
    regr = RandomForestRegressor(
        bootstrap = bootstrap, 
        criterion = criterion,
        max_depth = max_depth, 
        max_features = max_features,
        max_leaf_nodes = max_leaf_nodes,
        n_estimators = n_estimators,
        n_jobs=-1
        )
    
    score = cross_val_score(regr, X_train, y_train, cv=5, scoring="r2")
    r2_mean = score.mean()

    return r2_mean

#Execute optuna and set hyperparameters
study = optuna.create_study(direction='maximize')
study.optimize(rf_objetive, n_trials=100)

#Create an instance with tuned hyperparameters
optimised_rf = RandomForestRegressor(
    bootstrap = study.best_params['bootstrap'], 
    criterion = study.best_params['criterion'],
    max_depth = study.best_params['max_depth'], 
    max_features = study.best_params['max_features'],
    max_leaf_nodes = study.best_params['max_leaf_nodes'],
    n_estimators = study.best_params['n_estimators'],
    n_jobs=-1
    )

#learn
optimised_rf.fit(X_train ,y_train)

# Save the model
pickle.dump(optimised_rf, open('../models/rent_valencia_rf.pkl', 'wb'))
# Out:
# [I 2022-08-07 18:29:28,780] A new study created in memory with name: no-name-20175f16-3400-41c6-8432-99c01f8f72b8
# [I 2022-08-07 18:30:30,002] Trial 0 finished with value: 0.44025104203007637 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'False', 'max_depth': 9266, 'max_features': 'auto', 'max_leaf_nodes': 2644, 'n_estimators': 571}. Best is trial 0 with value: 0.44025104203007637.
# [I 2022-08-07 18:30:34,596] Trial 1 finished with value: 0.4364733291577417 and parameters: {'criterion': 'squared_error', 'bootstrap': 'True', 'max_depth': 7155, 'max_features': 'auto', 'max_leaf_nodes': 3032, 'n_estimators': 482}. Best is trial 0 with value: 0.44025104203007637.
# [I 2022-08-07 18:30:39,286] Trial 2 finished with value: 0.4282446864909124 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'False', 'max_depth': 3571, 'max_features': 'auto', 'max_leaf_nodes': 1479, 'n_estimators': 44}. Best is trial 0 with value: 0.44025104203007637.
# [I 2022-08-07 18:30:43,644] Trial 3 finished with value: 0.4578939639355841 and parameters: {'criterion': 'squared_error', 'bootstrap': 'True', 'max_depth': 2570, 'max_features': 'sqrt', 'max_leaf_nodes': 7028, 'n_estimators': 618}. Best is trial 3 with value: 0.4578939639355841.
# [I 2022-08-07 18:30:50,232] Trial 4 finished with value: 0.4374780185724962 and parameters: {'criterion': 'squared_error', 'bootstrap': 'True', 'max_depth': 2243, 'max_features': 'auto', 'max_leaf_nodes': 8915, 'n_estimators': 744}. Best is trial 3 with value: 0.4578939639355841.
# [I 2022-08-07 18:30:56,830] Trial 5 finished with value: 0.45720840086367504 and parameters: {'criterion': 'squared_error', 'bootstrap': 'False', 'max_depth': 7761, 'max_features': 'log2', 'max_leaf_nodes': 7733, 'n_estimators': 869}. Best is trial 3 with value: 0.4578939639355841.
# [I 2022-08-07 18:31:02,479] Trial 6 finished with value: 0.45685613722562446 and parameters: {'criterion': 'squared_error', 'bootstrap': 'True', 'max_depth': 8842, 'max_features': 'log2', 'max_leaf_nodes': 9246, 'n_estimators': 785}. Best is trial 3 with value: 0.4578939639355841.
# [I 2022-08-07 18:31:30,358] Trial 7 finished with value: 0.46078789973254264 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 4283, 'max_features': 'sqrt', 'max_leaf_nodes': 828, 'n_estimators': 998}. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:32:47,390] Trial 8 finished with value: 0.44110525078714036 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 3717, 'max_features': 'auto', 'max_leaf_nodes': 1606, 'n_estimators': 764}. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:32:54,214] Trial 9 finished with value: 0.4402301638857926 and parameters: {'criterion': 'squared_error', 'bootstrap': 'False', 'max_depth': 5280, 'max_features': 'auto', 'max_leaf_nodes': 609, 'n_estimators': 898}. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:33:03,314] Trial 10 finished with value: 0.45873538702694117 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 5692, 'max_features': 'sqrt', 'max_leaf_nodes': 5053, 'n_estimators': 315}. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:33:11,977] Trial 11 finished with value: 0.45814509097797823 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 368, 'max_features': 'sqrt', 'max_leaf_nodes': 5140, 'n_estimators': 306}. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:33:20,572] Trial 12 finished with value: 0.45767626030906994 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 5731, 'max_features': 'sqrt', 'max_leaf_nodes': 4789, 'n_estimators': 295}. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:33:31,225] Trial 13 finished with value: 0.4570761809246555 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 6508, 'max_features': 'sqrt', 'max_leaf_nodes': 4682, 'n_estimators': 355}. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:33:34,804] Trial 14 finished with value: 0.4539002159517298 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 4420, 'max_features': 'sqrt', 'max_leaf_nodes': 5972, 'n_estimators': 119}. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:33:46,736] Trial 15 finished with value: 0.45802918811353643 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 893, 'max_features': 'sqrt', 'max_leaf_nodes': 3576, 'n_estimators': 425}. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:33:50,714] Trial 16 finished with value: 0.3365604506907713 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth':
. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:42:00,072] Trial 36 finished with value: 0.45765399030472154 and parameters: {'criterion': 'squared_error', 'bootstrap': 'False', 'max_depth': 1738, 'max_features': 'log2', 'max_leaf_nodes': 1530, 'n_estimators': 916}. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:42:16,311] Trial 37 finished with value: 0.4531291025029138 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 9800, 'max_features': 'log2', 'max_leaf_nodes': 572, 'n_estimators': 595}. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:42:25,247] Trial 38 finished with value: 0.4374865420242278 and parameters: {'criterion': 'squared_error', 'bootstrap': 'True', 'max_depth': 2435, 'max_features': 'auto', 'max_leaf_nodes': 2338, 'n_estimators': 883}. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:42:53,873] Trial 39 finished with value: 0.4594548350669874 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 3289, 'max_features': 'log2', 'max_leaf_nodes': 4232, 'n_estimators': 1000}. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:43:01,176] Trial 40 finished with value: 0.43681564619999325 and parameters: {'criterion': 'squared_error', 'bootstrap': 'False', 'max_depth': 8227, 'max_features': 'auto', 'max_leaf_nodes': 2991, 'n_estimators': 759}. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:43:27,822] Trial 41 finished with value: 0.4604559475066553 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 1305, 'max_features': 'sqrt', 'max_leaf_nodes': 9930, 'n_estimators': 849}. Best is trial 7 with value: 0.46078789973254264.
# [I 2022-08-07 18:43:56,956] Trial 42 finished with value: 0.46123698219477316 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 1550, 'max_features': 'sqrt', 'max_leaf_nodes': 7971, 'n_estimators': 930}. Best is trial 42 with value: 0.46123698219477316.
# [I 2022-08-07 18:44:17,732] Trial 43 finished with value: 0.461358253404474 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 1525, 'max_features': 'sqrt', 'max_leaf_nodes': 8417, 'n_estimators': 661}. Best is trial 43 with value: 0.461358253404474.
# [I 2022-08-07 18:44:38,663] Trial 44 finished with value: 0.46174181513389023 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 112, 'max_features': 'sqrt', 'max_leaf_nodes': 7839, 'n_estimators': 668}. Best is trial 44 with value: 0.46174181513389023.
# [I 2022-08-07 18:44:55,585] Trial 45 finished with value: 0.46103573068524745 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 98, 'max_features': 'sqrt', 'max_leaf_nodes': 7981, 'n_estimators': 536}. Best is trial 44 with value: 0.46174181513389023.
# [I 2022-08-07 18:45:12,481] Trial 46 finished with value: 0.4600447118643009 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 118, 'max_features': 'sqrt', 'max_leaf_nodes': 7979, 'n_estimators': 537}. Best is trial 44 with value: 0.46174181513389023.
# [I 2022-08-07 18:45:32,952] Trial 47 finished with value: 0.4595472607774907 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 627, 'max_features': 'sqrt', 'max_leaf_nodes': 8150, 'n_estimators': 648}. Best is trial 44 with value: 0.46174181513389023.
# [I 2022-08-07 18:45:47,669] Trial 48 finished with value: 0.4599805150376386 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 471, 'max_features': 'sqrt', 'max_leaf_nodes': 7334, 'n_estimators': 463}. Best is trial 44 with value: 0.46174181513389023.
# [I 2022-08-07 18:45:52,219] Trial 49 finished with value: 0.4579939981996056 and parameters: {'criterion': 'squared_error', 'bootstrap': 'True', 'max_depth': 6763, 'max_features': 'sqrt', 'max_leaf_nodes': 8638, 'n_estimators': 551}. Best is trial 44 with value: 0.46174181513389023.
# [I 2022-08-07 18:46:07,275] Trial 50 finished with value: 0.4591957740250009 and parameters: {'criterion': 'absolute_error', 'bootstrap': 
. Best is trial 53 with value: 0.4619054796038927.
# [I 2022-08-07 18:56:25,703] Trial 87 finished with value: 0.45421511999895037 and parameters: {'criterion': 'squared_error', 'bootstrap': 'True', 'max_depth': 642, 'max_features': 'sqrt', 'max_leaf_nodes': 6382, 'n_estimators': 285}. Best is trial 53 with value: 0.4619054796038927.
# [I 2022-08-07 18:56:42,541] Trial 88 finished with value: 0.4587706645388245 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 999, 'max_features': 'sqrt', 'max_leaf_nodes': 8057, 'n_estimators': 512}. Best is trial 53 with value: 0.4619054796038927.
# [I 2022-08-07 18:57:04,211] Trial 89 finished with value: 0.45907031099272294 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 2395, 'max_features': 'sqrt', 'max_leaf_nodes': 6016, 'n_estimators': 643}. Best is trial 53 with value: 0.4619054796038927.
# [I 2022-08-07 18:57:13,396] Trial 90 finished with value: 0.45842725096325887 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 199, 'max_features': 'sqrt', 'max_leaf_nodes': 7061, 'n_estimators': 261}. Best is trial 53 with value: 0.4619054796038927.
# [I 2022-08-07 18:57:26,348] Trial 91 finished with value: 0.4593340373207555 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 38, 'max_features': 'sqrt', 'max_leaf_nodes': 8340, 'n_estimators': 387}. Best is trial 53 with value: 0.4619054796038927.
# [I 2022-08-07 18:57:44,972] Trial 92 finished with value: 0.45946775878939095 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 4068, 'max_features': 'sqrt', 'max_leaf_nodes': 8717, 'n_estimators': 525}. Best is trial 53 with value: 0.4619054796038927.
# [I 2022-08-07 18:58:13,630] Trial 93 finished with value: 0.4591041194470482 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 5778, 'max_features': 'sqrt', 'max_leaf_nodes': 7581, 'n_estimators': 893}. Best is trial 53 with value: 0.4619054796038927.
# [I 2022-08-07 18:58:44,179] Trial 94 finished with value: 0.45852134757833235 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 8755, 'max_features': 'sqrt', 'max_leaf_nodes': 5353, 'n_estimators': 957}. Best is trial 53 with value: 0.4619054796038927.
# [I 2022-08-07 18:58:59,111] Trial 95 finished with value: 0.4602420993951 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 1334, 'max_features': 'sqrt', 'max_leaf_nodes': 8000, 'n_estimators': 470}. Best is trial 53 with value: 0.4619054796038927.
# [I 2022-08-07 18:59:35,667] Trial 96 finished with value: 0.44085755171677954 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'False', 'max_depth': 488, 'max_features': 'auto', 'max_leaf_nodes': 3265, 'n_estimators': 319}. Best is trial 53 with value: 0.4619054796038927.
# [I 2022-08-07 18:59:39,542] Trial 97 finished with value: 0.4593391105220074 and parameters: {'criterion': 'squared_error', 'bootstrap': 'True', 'max_depth': 9143, 'max_features': 'sqrt', 'max_leaf_nodes': 7306, 'n_estimators': 554}. Best is trial 53 with value: 0.4619054796038927.
# [I 2022-08-07 18:59:53,640] Trial 98 finished with value: 0.4588534478122181 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 1129, 'max_features': 'sqrt', 'max_leaf_nodes': 4776, 'n_estimators': 449}. Best is trial 53 with value: 0.4619054796038927.
# [I 2022-08-07 19:00:17,182] Trial 99 finished with value: 0.4595876699123121 and parameters: {'criterion': 'absolute_error', 'bootstrap': 'True', 'max_depth': 249, 'max_features': 'sqrt', 'max_leaf_nodes': 9238, 'n_estimators': 746}. Best is trial 53 with value: 0.4619054796038927.

# %%
# Metrics
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

y_pred = optimised_rf.predict(X_test)
y_pred = inv_box_cox_transform(y_pred, lamda)
y_test = inv_box_cox_transform(y_test, lamda)

print('R2:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
print('MSE:', mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2: 0.38477504214777747
# MAE: 291.4603575217892
# MSE: 214799.6998303727
# RMSE: 463.4648852182576

# %%
# Plot feature importances
feature_importances = pd.DataFrame(
    optimised_rf.feature_importances_, 
    index=labels, 
    columns=['importance']).sort_values(by='importance', ascending=False)

feature_importances.plot(kind='barh', figsize=(10, 10))
plt.show()

# %%
Train = df_train.copy()
Test = df_test.copy()

# %%
feature_df = {'feature_droped': [], 'R2': [], 'MAE': [], 'MSE': [], 'RMSE': []}
features = list(feature_importances.index)[5:]

for i in reversed(features):
    Train.drop(i, axis=1, inplace=True)
    Test.drop(i, axis=1, inplace=True)
    
    X_train = Train
    X_test = Test

    optimised_rf.fit(X_train, y_train)
    y_pred = optimised_rf.predict(X_test)
    y_pred = inv_box_cox_transform(y_pred, lamda)

    feature_df['feature_droped'].append(i)
    feature_df['R2'].append(r2_score(y_test, y_pred))
    feature_df['MAE'].append(mean_absolute_error(y_test, y_pred))
    feature_df['MSE'].append(mean_squared_error(y_test, y_pred))
    feature_df['RMSE'].append(np.sqrt(mean_squared_error(y_test, y_pred)))

feature_df = pd.DataFrame(feature_df)
feature_df
# Out:
#                    feature_droped        R2         MAE            MSE  \
# 0                      isFinished  0.383710  291.327659  215171.489738
# 1                           renew  0.383218  292.208678  215343.399666
# 2                 new_development  0.383611  291.607982  215206.119079
# 3       propertyType_countryHouse  0.380646  292.217097  216241.332275
# 4             propertyType_studio  0.382793  291.040247  215491.727252
# 5               parkingSpacePrice  0.380174  292.584572  216406.054960
# 6                       has3DTour  0.385954  291.564676  214388.179355
# 7             propertyType_duplex  0.388024  291.841153  213665.349226
# 8                          has360  0.390450  290.772009  212818.395983
# 9          propertyType_penthouse  0.392586  291.586731  212072.740026
# 10                  cluster_north  0.390812  291.652809  212691.868500
# 11                       exterior  0.381511  293.063279  215939.264526
# 12              propertyType_flat  0.388417  294.471194  213528.240692
# 13                   cluster_west  0.380267  296.153827  216373.596293
# 14            propertyType_chalet  0.376701  297.391776  217618.627986
# 15  isParkingSpaceIncludedInPrice  0.380241  297.315960  216382.832084
# 16                  cluster_south  0.373067  299.210425  218887.541522
# 17                hasParkingSpace  0.365332  304.077610  221587.949653
# 18                        hasPlan  0.359232  304.940331  223717.680536
# 19                       hasVideo  0.362616  304.243388  222536.210793
# 20                        hasLift  0.357642  307.206507  224272.819095
# 21                cluster_central  0.333531  319.731031  232690.882020
#
#           RMSE
# 0   463.865810
# 1   464.051074
# 2   463.903135
# 3   465.017561
# 4   464.210865
# 5   465.194642
# 6   463.020712
# 7   462.239493
# 8   461.322443
# 9   460.513561
# 10  461.185287
# 11  464.692656
# 12  462.091161
# 13  465.159754
# 14  466.496118
# 15  465.169681
# 16  467.854188
# 17  470.731292
# 18  472.988034
# 19  471.737438
# 20  473.574513
# 21  482.380433

# %%
feature_df.sort_values(by='R2', ascending=False)
# Out:
#                    feature_droped        R2         MAE            MSE  \
# 9          propertyType_penthouse  0.392586  291.586731  212072.740026
# 10                  cluster_north  0.390812  291.652809  212691.868500
# 8                          has360  0.390450  290.772009  212818.395983
# 12              propertyType_flat  0.388417  294.471194  213528.240692
# 7             propertyType_duplex  0.388024  291.841153  213665.349226
# 6                       has3DTour  0.385954  291.564676  214388.179355
# 0                      isFinished  0.383710  291.327659  215171.489738
# 2                 new_development  0.383611  291.607982  215206.119079
# 1                           renew  0.383218  292.208678  215343.399666
# 4             propertyType_studio  0.382793  291.040247  215491.727252
# 11                       exterior  0.381511  293.063279  215939.264526
# 3       propertyType_countryHouse  0.380646  292.217097  216241.332275
# 13                   cluster_west  0.380267  296.153827  216373.596293
# 15  isParkingSpaceIncludedInPrice  0.380241  297.315960  216382.832084
# 5               parkingSpacePrice  0.380174  292.584572  216406.054960
# 14            propertyType_chalet  0.376701  297.391776  217618.627986
# 16                  cluster_south  0.373067  299.210425  218887.541522
# 17                hasParkingSpace  0.365332  304.077610  221587.949653
# 19                       hasVideo  0.362616  304.243388  222536.210793
# 18                        hasPlan  0.359232  304.940331  223717.680536
# 20                        hasLift  0.357642  307.206507  224272.819095
# 21                cluster_central  0.333531  319.731031  232690.882020
#
#           RMSE
# 9   460.513561
# 10  461.185287
# 8   461.322443
# 12  462.091161
# 7   462.239493
# 6   463.020712
# 0   463.865810
# 2   463.903135
# 1   464.051074
# 4   464.210865
# 11  464.692656
# 3   465.017561
# 13  465.159754
# 15  465.169681
# 5   465.194642
# 14  466.496118
# 16  467.854188
# 17  470.731292
# 19  471.737438
# 18  472.988034
# 20  473.574513
# 21  482.380433

# %%
feature_df.sort_values(by='RMSE')
# Out:
#                    feature_droped        R2         MAE            MSE  \
# 9          propertyType_penthouse  0.392586  291.586731  212072.740026
# 10                  cluster_north  0.390812  291.652809  212691.868500
# 8                          has360  0.390450  290.772009  212818.395983
# 12              propertyType_flat  0.388417  294.471194  213528.240692
# 7             propertyType_duplex  0.388024  291.841153  213665.349226
# 6                       has3DTour  0.385954  291.564676  214388.179355
# 0                      isFinished  0.383710  291.327659  215171.489738
# 2                 new_development  0.383611  291.607982  215206.119079
# 1                           renew  0.383218  292.208678  215343.399666
# 4             propertyType_studio  0.382793  291.040247  215491.727252
# 11                       exterior  0.381511  293.063279  215939.264526
# 3       propertyType_countryHouse  0.380646  292.217097  216241.332275
# 13                   cluster_west  0.380267  296.153827  216373.596293
# 15  isParkingSpaceIncludedInPrice  0.380241  297.315960  216382.832084
# 5               parkingSpacePrice  0.380174  292.584572  216406.054960
# 14            propertyType_chalet  0.376701  297.391776  217618.627986
# 16                  cluster_south  0.373067  299.210425  218887.541522
# 17                hasParkingSpace  0.365332  304.077610  221587.949653
# 19                       hasVideo  0.362616  304.243388  222536.210793
# 18                        hasPlan  0.359232  304.940331  223717.680536
# 20                        hasLift  0.357642  307.206507  224272.819095
# 21                cluster_central  0.333531  319.731031  232690.882020
#
#           RMSE
# 9   460.513561
# 10  461.185287
# 8   461.322443
# 12  462.091161
# 7   462.239493
# 6   463.020712
# 0   463.865810
# 2   463.903135
# 1   464.051074
# 4   464.210865
# 11  464.692656
# 3   465.017561
# 13  465.159754
# 15  465.169681
# 5   465.194642
# 14  466.496118
# 16  467.854188
# 17  470.731292
# 19  471.737438
# 18  472.988034
# 20  473.574513
# 21  482.380433

# %% [markdown]
# ### Conclusion
#
# * Our better random forest is with only 17 features, so we need to drop 9 features to get the best model.
# * Still have a RMSE error to high for predict Rent.
# * Our next try will be trying with neural network.
