# %%
# Required libraries
import os
from dotenv import load_dotenv, find_dotenv
import base64
import urllib
import requests as rq
import json
import pandas as pd
import time

# %%
# Get authentication token
def get_oauth_token():

    url = "https://api.idealista.com/oauth/token"

    load_dotenv(find_dotenv('creds.env')) # Load .env file
    apikey = os.environ.get("API_KEY")
    secret = os.environ.get("SECRET")
    apikey_secret = apikey + ':' + secret

    auth = str(base64.b64encode(bytes(apikey_secret, 'utf-8')))[2:][:-1] # Get base64 encoded string

    headers = {'Authorization' : 'Basic ' + auth,'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'}
    params = urllib.parse.urlencode({'grant_type':'client_credentials'}) #,'scope':'read'
    content = rq.post(url,headers = headers, params=params) # Get response
    bearer_token = json.loads(content.text)['access_token'] # Get access token

    return bearer_token

# %%
# Get list of properties
def search_api(token, params):
    url = "https://api.idealista.com/3.5/es/search"

    headers = {'Content-Type': 'Content-Type: multipart/form-data;', 'Authorization' : 'Bearer ' + token} 
    content = rq.post(url, headers=headers, params=params) # Get response
    
    print(content)
    return content

# %% [markdown]
# **Note**: *locationId* goes from 0-EU-ES-01 to 0-EU-ES-56 for Spain.
#
# **REQUIREMENTS**:
# - country = ['es', 'it', 'pt']
# - operation = ['sale', 'rent']
# - propertyType = ['homes', 'offices', 'premises', 'garages', 'bedrooms']
# - you must specify a center + distance or locationId in each request

# %%
params = {
    "country" : 'es',
    "operation" : "rent",
    "propertyType" : "homes",
    "locationId" : "0-EU-ES-46",
    "maxItems" : 50,
}

# Test connection
token = get_oauth_token()
result = search_api(token, params)
# Out:
# <Response [200]>

# %%
# Print result
result.text
# Out:
# '{"elementList":[{"propertyCode":"97693036","thumbnail":"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/cb/2b/e3/987270204.jpg","externalReference":"AV2203006-1","numPhotos":30,"floor":"11","price":1500.0,"propertyType":"penthouse","operation":"rent","size":80.0,"exterior":true,"rooms":3,"bathrooms":2,"address":"Avenida de la Tarongina","province":"València","municipality":"Tavernes de la Valldigna","country":"es","latitude":39.1010767,"longitude":-0.2241471,"showAddress":false,"url":"https://www.idealista.com/inmueble/97693036/","description":"Ático en alquiler en Tavernes de la Valldigna   Ático luminoso en Tavernes de la Valldigna para alquiler vacacional. Tiene tres habitaciones, dos cuartos de baño, terraza muy amplia acristalada (45m2), terraza muy grande solarium (70m2) en la parte superior del apartamento. En el precio estaría incluida una plaza de garaje. La vivienda es un ático, está en una planta 11 con vistas espectaculares, mucha luz y muy ventilado. Tiene internet, esto iría a parte del precio. El apartamento sin contar terrazas tiene una superficie de aprox. 80 m2. Precios según temporada. Solo queda disponible el mes completo de Junio, primera quincena de Julio y mes completo de Septiembre. No dude en ponerse en contacto con nosotros, estaremos encantados de atenderle.","hasVideo":true,"status":"good","newDevelopment":false,"hasLift":true,"parkingSpace":{"hasParkingSpace":true,"isParkingSpaceIncludedInPrice":true},"priceByArea":19.0,"detailedType":{"typology":"flat","subTypology":"penthouse"},"suggestedTexts":{"subtitle":"Tavernes de la Valldigna","title":"Ático en Avenida de la Tarongina"},"hasPlan":false,"has3DTour":false,"has360":false,"hasStaging":false,"topNewDevelopment":false},{"propertyCode":"98039610","thumbnail":"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/1b/a7/a5/999079559.jpg","externalReference":"AV2206084","numPhotos":18,"floor":"3","price":1600.0,"propertyType":"flat","operation":"rent","size":193.0,"exterior":true,"rooms":4,"bathrooms":1,"address":"Pinedo","province":"València","municipality":"Pinedo","country":"es","latitude":39.4207254,"longitude":-0.342421,"showAddress":false,"url":"https://www.idealista.com/inmueble/98039610/","description":"Piso en alquiler de 4 habitaciones en Pinedo Aproperties le presenta este magnífico piso en Pinedo. Este piso de 193 m², está distribuido en 4 amplias habitaciones con mucha luz natural. Dispone de un gran salón comedor, una cocina equipada y un baño. El piso está totalmente equipado, listo para entrar a vivir. Tiene calefacción central y aire acondicionado. Está situado en la 3ª plata, lo que le proporciona mucha iluminación. La zona dispone de excelentes servicios tales como, la playa, supermercados, farmacias, restaurantes, etc. Si desea más información sobre esta propiedad, no dude en contactar con nosotros, estaremos encantados de atenderle.","hasVideo":false,"status":"good","newDevelopment":false,"hasLift":true,"priceByArea":8.0,"detailedType":{"typology":"flat"},"suggestedTexts":{"subtitle":"Pinedo","title":"Piso"},"hasPlan":false,"has3DTour":false,"has360":false,"hasStaging":false,"topNewDevelopment":false},{"propertyCode":"98042660","thumbnail":"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/4c/8b/b7/999164714.jpg","externalReference":"IM648","numPhotos":9,"floor":"3","price":850.0,"propertyType":"flat","operation":"rent","size":110.0,"exterior":true,"rooms":3,"bathrooms":1,"address":"Calle Benasal","province":"València","municipality":"València","district":"Poblats Marítims","country":"es","neighborhood":"El Cabanyal-El Canyamelar","latitude":39.46359,"longitude":-0.3274681,"showAddress":false,"url":"https://www.idealista.com/inmueble/98042660/","description":"SOLO ALQUILERES, les ofrece este magnifico piso FRENTE A LA PLAYA, para disfrutar todo el año y con todos los servicios cerca, autobuses, tranvía, etc. Se distribuye en comedor salón muy luminoso, con una amplia cocina  ...

# %%
# get totalPages
totalPages = json.loads(result.text)['totalPages']
print(totalPages)
# Out:
# 53

# %%
# get actual page
actualPage = json.loads(result.text)['actualPage']
print(actualPage)
# Out:
# 1

# %%
df_tot = pd.DataFrame(json.loads(result.text)["elementList"])
df_tot
# Out:
#    propertyCode                                          thumbnail  \
# 0      97693036  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1      98039610  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2      98042660  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3      98042528  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4      98042519  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 5      98042463  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 6      98042205  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 7      97791775  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 8      97725193  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 9      98042144  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 10     98042096  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 11     98042077  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 12     93429739  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 13     98041994  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 14     98041979  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 15     98041736  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 16     98041224  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 17     96230035  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 18     98040986  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 19     98040798  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 20     98040635  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 21     98040601  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 22     93527451  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 23     88617288  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 24     98040198  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 25     98040156  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 26     93741608  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 27     90572683  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 28     98039944  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 29     97948119  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 30     97993156  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 31     98009651  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 32     98009662  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 33     98025184  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 34     98025196  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 35     98037636  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 36     95481391  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 37     98039736  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 38     91025596  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 39     98039625  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 40     98039623  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 41     98039608  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 42     82389659  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 43     98039560  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 44     98039405  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 45     97922847  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 46     98039381  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 47     98039236  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 48     87466053  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 49     98039085  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#           externalReference  numPhotos floor   price propertyType operation  \
# 0               AV2203006-1         30    11  1500.0    penthouse      rent
# 1                 AV2206084         18     3  1600.0         flat      rent
# 2                     IM648          9     3   850.0         flat      rent
# 3                     V1134         29     3   950.0         flat      rent
# 4                 AV2206086         18    bj   900.0         flat      rent
# 5                     11100         15     3  1290.0         flat      rent
# 6                  p-puig50         47     1   800.0         flat      rent
# 7                       NaN         40     2  1700.0         flat      rent
# 8                       NaN         39     1  1700.0         flat      rent
# 9                       NaN         16     4   800.0         flat      rent
# 10                  PIS3035         45     4   750.0         flat      rent
# 11                  PIS0116          8    bj   630.0         flat      rent
# 12  3604-VI-027-053-003-005         16     3   460.0         flat      rent
# 13                     1325         22     6   850.0         flat      rent
# 14                AV2206085         18    bj  1200.0         flat      rent
# 15                  LD00161          6     9   700.0    penthouse      rent
# 16                  A-PF900         35     4   900.0         flat      rent
# 17                  HVC0030         24     4   850.0         flat      rent
# 18                    561CA         33     3   900.0         flat      rent
# 19                    08194          9     6  1100.0    penthouse      rent
# 20                      NaN         10    11   900.0         flat      rent
# 21                       pl         25     3  1200.0         flat      rent
# 22                  PIS_333         32     4  1100.0         flat      rent
# 23                 88273519         17     1   800.0         flat      rent
# 24                COS-00526         22     1  2000.0         flat      rent
# 25                    P6348         19     1   700.0         flat      rent
# 26               2593096783         20     1   800.0         flat      rent
# 27                      NaN         18     2  1200.0         flat      rent
# 28                    A5272         18     8  1900.0         flat      rent
# 29                VALR15996         60   NaN  4000.0       chalet      rent
# 30                VALR27554         42   NaN  1900.0         flat      rent
# 31                VALR35143         53   NaN  3700.0       chalet      rent
# 32                VALR35159         22   NaN  1700.0         flat      rent
# 33                 VALR7791         34   NaN  3700.0    penthouse      rent
# 34                VALR35189         32   NaN  2100.0         flat      rent
# 35                VALR21917         42   NaN  3500.0         flat      rent
# 36                      NaN         45     8  1500.0    penthouse      rent
# 37                 LCGV-138         31     8  1400.0         flat      rent
# 38                46-247981          2     3   575.0         flat      rent
# 39              AV2206053-1         28   NaN  3600.0       chalet      rent
# 40              AV2205118-1         25   NaN  1400.0         flat      rent
# 41              AV2205075-1         31     2  1800.0         flat      rent
# 42                      NaN          9     7   750.0         flat      rent
# 43                    JA362         25     1  1000.0         flat      rent
# 44                      NaN         10     7   850.0    penthouse      rent
# 45                 ACA-1289         20   NaN  1600.0       chalet      rent
# 46                    17316         14     4   650.0         flat      rent
# 47                      NaN         16     2   700.0    penthouse      rent
# 48                 Pl-03104         34     8  1200.0    penthouse      rent
# 49                    14345         11     2   650.0         flat      rent
#
#      size  exterior  ...                                       detailedType  \
# 0    80.0      True  ...   {'typology': 'flat', 'subTypology': 'penthouse'}
# 1   193.0      True  ...                               {'typology': 'flat'}
# 2   110.0      True  ...                               {'typology': 'flat'}
# 3   101.0      True  ...                               {'typology': 'flat'}
# 4    45.0      True  ...                               {'typology': 'flat'}
# 5   110.0      True  ...                               {'typology': 'flat'}
# 6   100.0      True  ...                               {'typology': 'flat'}
# 7   113.0      True  ...                               {'typology': 'flat'}
# 8   110.0      True  ...                               {'typology': 'flat'}
# 9    71.0      True  ...                               {'typology': 'flat'}
# 10   64.0      True  ...                               {'typology': 'flat'}
# 11   65.0      True  ...                               {'typology': 'flat'}
# 12   92.0      True  ...                               {'typology': 'flat'}
# 13   96.0      True  ...                               {'typology': 'flat'}
# 14   56.0      True  ...                               {'typology': 'flat'}
# 15   70.0      True  ...   {'typology': 'flat', 'subTypology': 'penthouse'}
# 16  100.0      True  ...                               {'typology': 'flat'}
# 17   59.0      True  ...                               {'typology': 'flat'}
# 18  105.0      True  ...                               {'typology': 'flat'}
# 19   85.0      True  ...   {'typology': 'flat', 'subTypology': 'penthouse'}
# 20  100.0      True  ...                               {'typology': 'flat'}
# 21   77.0      True  ...                               {'typology': 'flat'}
# 22  130.0      True  ...                               {'typology': 'flat'}
# 23   85.0      True  ...                               {'typology': 'flat'}
# 24   92.0      True  ...                               {'typology': 'flat'}
# 25   84.0      True  ...                               {'typology': 'flat'}
# 26   70.0      True  ...                               {'typology': 'flat'}
# 27  120.0      True  ...                               {'typology': 'flat'}
# 28  174.0      True  ...                               {'typology': 'flat'}
# 29  437.0     False  ...                             {'typology': 'chalet'}
# 30  191.0      True  ...                               {'typology': 'flat'}
# 31  533.0     False  ...                             {'typology': 'chalet'}
# 32  134.0     False  ...                               {'typology': 'flat'}
# 33  215.0      True  ...   {'typology': 'flat', 'subTypology': 'penthouse'}
# 34  162.0      True  ...                               {'typology': 'flat'}
# 35  188.0      True  ...                               {'typology': 'flat'}
# 36  106.0      True  ...   {'typology': 'flat', 'subTypology': 'penthouse'}
# 37  149.0      True  ...                               {'typology': 'flat'}
# 38   53.0     False  ...                               {'typology': 'flat'}
# 39  280.0     False  ...  {'typology': 'chalet', 'subTypology': 'indepen...
# 40   90.0      True  ...                               {'typology': 'flat'}
# 41  124.0      True  ...                               {'typology': 'flat'}
# 42   80.0      True  ...                               {'typology': 'flat'}
# 43   75.0      True  ...                               {'typology': 'flat'}
# 44   75.0      True  ...   {'typology': 'flat', 'subTypology': 'penthouse'}
# 45  200.0     False  ...  {'typology': 'chalet', 'subTypology': 'terrace...
# 46   48.0      True  ...                               {'typology': 'flat'}
# 47   85.0      True  ...   {'typology': 'flat', 'subTypology': 'penthouse'}
# 48   98.0      True  ...   {'typology': 'flat', 'subTypology': 'penthouse'}
# 49   75.0      True  ...                               {'typology': 'flat'}
#
#                                        suggestedTexts hasPlan has3DTour  \
# 0   {'subtitle': 'Tavernes de la Valldigna', 'titl...   False     False
# 1             {'subtitle': 'Pinedo', 'title': 'Piso'}   False     False
# 2   {'subtitle': 'El Cabanyal-El Canyamelar, Valèn...   False     False
# 3   {'subtitle': 'El Carme, València', 'title': 'P...   False     False
# 4   {'subtitle': 'El Pilar, València', 'title': 'P...   False     False
# 5   {'subtitle': 'El Pla del Remei, València', 'ti...   False     False
# 6   {'subtitle': 'Sotolivar - Mas del Rosari, Pate...   False     False
# 7   {'subtitle': 'La Carrasca, València', 'title':...   False     False
# 8   {'subtitle': 'L'Illa Perduda, València', 'titl...   False     False
# 9   {'subtitle': 'Nou Moles, València', 'title': '...   False     False
# 10  {'subtitle': 'Russafa, València', 'title': 'Pi...   False     False
# 11  {'subtitle': 'Benicalap, València', 'title': '...    True     False
# 12  {'subtitle': 'Sants Patrons, Alzira', 'title':...   False     False
# 13  {'subtitle': 'Sant Llorenç, València', 'title'...   False      True
# 14  {'subtitle': 'El Pilar, València', 'title': 'P...   False     False
# 15  {'subtitle': 'La Torre', 'title': 'Ático en Ca...   False     False
# 16  {'subtitle': 'Aiora, València', 'title': 'Piso...   False     False
# 17  {'subtitle': 'L'Amistat, València', 'title': '...   False     False
# 18         {'subtitle': 'Benimàmet', 'title': 'Piso'}   False     False
# 19  {'subtitle': 'Gran Vía, València', 'title': 'Á...   False     False
# 20  {'subtitle': 'La Carrasca, València', 'title':...   False     False
# 21  {'subtitle': 'La Xerea, València', 'title': 'P...   False     False
# 22  {'subtitle': 'Campanar, València', 'title': 'P...   False     False
# 23  {'subtitle': 'Playa de la Malvarrosa, València...   False     False
# 24  {'subtitle': 'Riba-Roja de Túria', 'title': 'P...   False     False
# 25  {'subtitle': 'Playa de la Malvarrosa, València...   False     False
# 26  {'subtitle': 'Playa de la Malvarrosa, València...   False     False
# 27  {'subtitle': 'L'Illa Perduda, València', 'titl...   False     False
# 28  {'subtitle': 'Sant Francesc, València', 'title...   False     False
# 29        {'subtitle': 'Rocafort', 'title': 'Chalet'}   False     False
# 30  {'subtitle': 'Sant Francesc, València', 'title...   False     False
# 31  {'subtitle': 'Los Monasterios-Alfinach, Puçol'...   False     False
# 32  {'subtitle': 'Ciutat de les Arts i de les Cien...   False     False
# 33  {'subtitle': 'Gran Vía, València', 'title': 'Á...   False     False
# 34  {'subtitle': 'El Pla del Remei, València', 'ti...   False     False
# 35  {'subtitle': 'El Pla del Remei, València', 'ti...   False     False
# 36  {'subtitle': 'La Roqueta, València', 'title': ...    True     False
# 37  {'subtitle': 'Arrancapins, València', 'title':...   False     False
# 38  {'subtitle': 'Els Orriols, València', 'title':...   False     False
# 39  {'subtitle': 'Corral Nou - Montros - Estepar, ...   False     False
# 40  {'subtitle': 'Malilla, València', 'title': 'Pi...   False     False
# 41  {'subtitle': 'La Xerea, València', 'title': 'P...   False     False
# 42  {'subtitle': 'La Vega Baixa, València', 'title...   False     False
# 43  {'subtitle': 'Malilla, València', 'title': 'Pi...    True     False
# 44  {'subtitle': 'La Roqueta, València', 'title': ...   False     False
# 45  {'subtitle': 'Port Saplaya, Alboraya', 'title'...   False     False
# 46   {'subtitle': 'Quart de Poblet', 'title': 'Piso'}   False     False
# 47  {'subtitle': 'La Torre', 'title': 'Ático en gi...   False     False
# 48  {'subtitle': 'Playa de Farnals', 'title': 'Áti...   False     False
# 49  {'subtitle': 'La Roqueta, València', 'title': ...   False     False
#
#    has360 hasStaging  topNewDevelopment                        district  \
# 0   False      False              False                             NaN
# 1   False      False              False                             NaN
# 2   False      False              False                Poblats Marítims
# 3    True      False              False                    Ciutat Vella
# 4   False      False              False                    Ciutat Vella
# 5   False      False              False                      L'Eixample
# 6   False      False              False      Sotolivar - Mas del Rosari
# 7   False      False              False                         Algirós
# 8   False      False              False                         Algirós
# 9   False      False              False                     L'Olivereta
# 10  False      False              False                      L'Eixample
# 11  False      False              False                       Benicalap
# 12  False      False              False                       Casc Urbà
# 13  False      False              False                        Rascanya
# 14  False      False              False                    Ciutat Vella
# 15  False      False              False                             NaN
# 16  False      False              False                  Camins al Grau
# 17  False      False              False                         Algirós
# 18  False      False              False                             NaN
# 19  False      False              False                      L'Eixample
# 20  False      False              False                         Algirós
# 21  False      False              False                    Ciutat Vella
# 22  False      False              False                        Campanar
# 23  False      False              False                Poblats Marítims
# 24  False      False              False                             NaN
# 25  False      False              False                Poblats Marítims
# 26  False      False              False                Poblats Marítims
# 27  False      False              False                         Algirós
# 28  False      False              False                    Ciutat Vella
# 29  False      False              False                             NaN
# 30  False      False              False                    Ciutat Vella
# 31  False      False              False        Los Monasterios-Alfinach
# 32  False      False              False                 Quatre Carreres
# 33  False      False              False                      L'Eixample
# 34  False      False              False                      L'Eixample
# 35  False      False              False                      L'Eixample
# 36  False      False              False                       Extramurs
# 37  False      False              False                       Extramurs
# 38  False      False              False                        Rascanya
# 39  False      False              False  Corral Nou - Montros - Estepar
# 40  False      False              False                 Quatre Carreres
# 41  False      False              False                    Ciutat Vella
# 42  False      False              False                         Algirós
# 43  False      False              False                 Quatre Carreres
# 44  False      False              False                       Extramurs
# 45  False      False              False                    Port Saplaya
# 46  False      False              False                             NaN
# 47  False      False              False                             NaN
# 48  False      False              False                             NaN
# 49  False      False              False                       Extramurs
#
#                             neighborhood  \
# 0                                    NaN
# 1                                    NaN
# 2              El Cabanyal-El Canyamelar
# 3                               El Carme
# 4                               El Pilar
# 5                       El Pla del Remei
# 6                                    NaN
# 7                            La Carrasca
# 8                         L'Illa Perduda
# 9                              Nou Moles
# 10                               Russafa
# 11                             Benicalap
# 12                         Sants Patrons
# 13                          Sant Llorenç
# 14                              El Pilar
# 15                                   NaN
# 16                                 Aiora
# 17                             L'Amistat
# 18                                   NaN
# 19                              Gran Vía
# 20                           La Carrasca
# 21                              La Xerea
# 22                              Campanar
# 23                Playa de la Malvarrosa
# 24                                   NaN
# 25                Playa de la Malvarrosa
# 26                Playa de la Malvarrosa
# 27                        L'Illa Perduda
# 28                         Sant Francesc
# 29                                   NaN
# 30                         Sant Francesc
# 31                                   NaN
# 32  Ciutat de les Arts i de les Ciencies
# 33                              Gran Vía
# 34                      El Pla del Remei
# 35                      El Pla del Remei
# 36                            La Roqueta
# 37                           Arrancapins
# 38                           Els Orriols
# 39                                   NaN
# 40                               Malilla
# 41                              La Xerea
# 42                         La Vega Baixa
# 43                               Malilla
# 44                            La Roqueta
# 45                                   NaN
# 46                                   NaN
# 47                                   NaN
# 48                                   NaN
# 49                            La Roqueta
#
#                                       labels
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29  [{'name': 'luxuryType', 'text': 'Lujo'}]
# 30                                       NaN
# 31  [{'name': 'luxuryType', 'text': 'Lujo'}]
# 32                                       NaN
# 33                                       NaN
# 34                                       NaN
# 35                                       NaN
# 36                                       NaN
# 37                                       NaN
# 38                                       NaN
# 39  [{'name': 'villaType', 'text': 'Villa'}]
# 40                                       NaN
# 41                                       NaN
# 42                                       NaN
# 43                                       NaN
# 44                                       NaN
# 45                                       NaN
# 46                                       NaN
# 47                                       NaN
# 48                                       NaN
# 49                                       NaN
#
# [50 rows x 37 columns]

# %%
for i in range(2, totalPages):
    try:
        params['numPage'] = i
        result = search_api(token, params)
        df = pd.DataFrame(json.loads(result.text)["elementList"])
        df_tot = pd.concat([df_tot, df])
        time.sleep(5)
    except Exception as e:
        print(e, "Page: ", i)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
df_tot.reset_index(drop=True, inplace=True)

# %%
# ¿All the propertyCode are unique?
df_tot['propertyCode'].nunique()
# Out:
# 2600

# %%
df_tot
# Out:
#      propertyCode                                          thumbnail  \
# 0        97693036  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1        98039610  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2        98042660  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3        98042528  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4        98042519  https://img3.idealista.com/blur/WEB_LISTING/0/...
# ...           ...                                                ...
# 2595     97334169  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2596     88772862  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2597     94396615  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2598     98010151                                                NaN
# 2599     97996918                                                NaN
#
#      externalReference  numPhotos floor   price propertyType operation   size  \
# 0          AV2203006-1         30    11  1500.0    penthouse      rent   80.0
# 1            AV2206084         18     3  1600.0         flat      rent  193.0
# 2                IM648          9     3   850.0         flat      rent  110.0
# 3                V1134         29     3   950.0         flat      rent  101.0
# 4            AV2206086         18    bj   900.0         flat      rent   45.0
# ...                ...        ...   ...     ...          ...       ...    ...
# 2595            V-1616         19     1   450.0         flat      rent   86.0
# 2596              9853          8    bj   500.0         flat      rent   60.0
# 2597       46-205-4752          9     4   600.0         flat      rent   45.0
# 2598             26133          0     2   560.0         flat      rent  126.0
# 2599             29055          0     7   550.0         flat      rent  120.0
#
#       exterior  ...                                     suggestedTexts  \
# 0         True  ...  {'subtitle': 'Tavernes de la Valldigna', 'titl...
# 1         True  ...            {'subtitle': 'Pinedo', 'title': 'Piso'}
# 2         True  ...  {'subtitle': 'El Cabanyal-El Canyamelar, Valèn...
# 3         True  ...  {'subtitle': 'El Carme, València', 'title': 'P...
# 4         True  ...  {'subtitle': 'El Pilar, València', 'title': 'P...
# ...        ...  ...                                                ...
# 2595      True  ...           {'subtitle': 'Alginet', 'title': 'Piso'}
# 2596      True  ...  {'subtitle': 'Bonrepos i Mirambell', 'title': ...
# 2597      True  ...  {'subtitle': 'La Petxina, València', 'title': ...
# 2598      True  ...  {'subtitle': 'Zona Concordia, Burjassot', 'tit...
# 2599      True  ...  {'subtitle': 'Cardenal Benlloch, Mislata', 'ti...
#
#       hasPlan has3DTour has360 hasStaging topNewDevelopment  \
# 0       False     False  False      False             False
# 1       False     False  False      False             False
# 2       False     False  False      False             False
# 3       False     False   True      False             False
# 4       False     False  False      False             False
# ...       ...       ...    ...        ...               ...
# 2595    False     False  False      False             False
# 2596    False     False  False      False             False
# 2597    False     False  False      False             False
# 2598    False     False  False      False             False
# 2599    False     False  False      False             False
#
#                district               neighborhood  \
# 0                   NaN                        NaN
# 1                   NaN                        NaN
# 2      Poblats Marítims  El Cabanyal-El Canyamelar
# 3          Ciutat Vella                   El Carme
# 4          Ciutat Vella                   El Pilar
# ...                 ...                        ...
# 2595                NaN                        NaN
# 2596                NaN                        NaN
# 2597          Extramurs                 La Petxina
# 2598     Zona Concordia                        NaN
# 2599  Cardenal Benlloch                        NaN
#
#                                                  labels newDevelopmentFinished
# 0                                                   NaN                    NaN
# 1                                                   NaN                    NaN
# 2                                                   NaN                    NaN
# 3                                                   NaN                    NaN
# 4                                                   NaN                    NaN
# ...                                                 ...                    ...
# 2595                                                NaN                    NaN
# 2596                                                NaN                    NaN
# 2597  [{'name': 'apartamentoType', 'text': 'Apartame...                    NaN
# 2598                                                NaN                    NaN
# 2599                                                NaN                    NaN
#
# [2600 rows x 38 columns]

# %% [markdown]
# **END OF TEST**, next step is to make a file named 'make_data.py' that will generate the data for the analysis.

# %%
df_tot.to_csv('../data/rent_Valencia.csv', index=False)
