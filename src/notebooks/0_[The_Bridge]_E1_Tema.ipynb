# %% [markdown]
# # Primera entrega ML - Carlos I. Cabruja Rodil

# %% [markdown]
# ### Título de proyecto

# %% [markdown]
# # Modelización del precio de alquiler de una vivienda en la provincia de Valencia

# %% [markdown]
# ### Tema

# %% [markdown]
# El objetivo de este proyecto consiste en realizar una estimación fiable del precio del alquiler de una vivienda en la provincia de Valencia a partir de los atributos de cada inmueble; atributos como el número de habitaciones, el tipo de vivienda, la ubicación, etc.
#
# Como punto de partida para nuestro análisis se utilizará los datos obtenidos gracias a la API de Idealista (el portal inmobiliario más popular en España) que nos proporciona una lista de inmuebles de la provincia de Valencia, con la información de cada inmueble, como el precio de alquiler, el número de habitaciones, el tipo de vivienda, etc.
#
# La utilidad de este modelo de regresión no será solo la estimación del precio de alquiler de una vivienda, sino que también servirá como una herramienta para la toma de decisiones en el momento de decidir alquilar el inmueble, ya que con este modelo podremos ver si la publicación de ese inmueble que el usuario quiere alquilar está sobrevalorado por el usuario que ha publicado ese inmueble. Sirviendo así como una herramienta para proteger al usuario en contra de la especulación de otros usuarios.

# %% [markdown]
# ### Datasets y fuentes alternativas de datos
# Incluye aquí una breve descripción del dataset o datasets para tu proyecto. Incluye también las fuentes de cada uno de ellos.

# %%
tipo_ml = "Regresión" # Regresión? Clasificación?
target_descr = "Precio del Alquiler" # Descripción de la variable objetivo
metricas = ["Coeficiente de determinación", "RMSE", "MAE"] # Metricas escogidas para evaluar los modelos

# %%
# dasets y enlaces de datasets en Markdown
enlaces = ["https://developers.idealista.com/access-request", "https://api.idealista.com/3.5/es/search"] # ["www.paginacondatos.com", "www.paginawebscrapeada.com", "www.unaapi.com"]

# %% [markdown]
# - https://developers.idealista.com/access-request (Pedir accesso a la API)
# - https://api.idealista.com/3.5/es/search (API de Idealista 3.5)

# %%
import pandas as pd
# load dataset
df_1 = pd.read_csv("../data/rent_Valencia.csv")
df_1.head()
# Out:
#    propertyCode                                          thumbnail  \
# 0      97693036  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1      98039610  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2      98042660  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3      98042528  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4      98042519  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#   externalReference  numPhotos floor   price propertyType operation   size  \
# 0       AV2203006-1         30    11  1500.0    penthouse      rent   80.0
# 1         AV2206084         18     3  1600.0         flat      rent  193.0
# 2             IM648          9     3   850.0         flat      rent  110.0
# 3             V1134         29     3   950.0         flat      rent  101.0
# 4         AV2206086         18    bj   900.0         flat      rent   45.0
#
#    exterior  ...                                     suggestedTexts  hasPlan  \
# 0      True  ...  {'subtitle': 'Tavernes de la Valldigna', 'titl...    False
# 1      True  ...            {'subtitle': 'Pinedo', 'title': 'Piso'}    False
# 2      True  ...  {'subtitle': 'El Cabanyal-El Canyamelar, Valèn...    False
# 3      True  ...  {'subtitle': 'El Carme, València', 'title': 'P...    False
# 4      True  ...  {'subtitle': 'El Pilar, València', 'title': 'P...    False
#
#   has3DTour has360 hasStaging topNewDevelopment          district  \
# 0     False  False      False             False               NaN
# 1     False  False      False             False               NaN
# 2     False  False      False             False  Poblats Marítims
# 3     False   True      False             False      Ciutat Vella
# 4     False  False      False             False      Ciutat Vella
#
#                 neighborhood  labels newDevelopmentFinished
# 0                        NaN     NaN                    NaN
# 1                        NaN     NaN                    NaN
# 2  El Cabanyal-El Canyamelar     NaN                    NaN
# 3                   El Carme     NaN                    NaN
# 4                   El Pilar     NaN                    NaN
#
# [5 rows x 38 columns]

# %%
# load dataset
df_2 = pd.read_csv("../data/rent_Valencia_cleaned.csv")
df_2.head()
# Out:
#    propertyCode  numPhotos  floor   price propertyType   size  exterior  \
# 0      97693036         30     11  1500.0    penthouse   80.0      True
# 1      98039610         18      3  1600.0         flat  193.0      True
# 2      98042660          9      3   850.0         flat  110.0      True
# 3      98042528         29      3   950.0         flat  101.0      True
# 4      98042519         18      0   900.0         flat   45.0      True
#
#    rooms  bathrooms   latitude  ...  priceByArea  hasPlan has3DTour  has360  \
# 0      3          2  39.101077  ...         19.0    False     False   False
# 1      4          1  39.420725  ...          8.0    False     False   False
# 2      3          1  39.463590  ...          8.0    False     False   False
# 3      3          2  39.479151  ...          9.0    False     False    True
# 4      1          1  39.474174  ...         20.0    False     False   False
#
#    hasStaging  topNewDevelopment  newDevelopmentFinished  hasParkingSpace  \
# 0       False              False                    True             True
# 1       False              False                    True            False
# 2       False              False                    True            False
# 3       False              False                    True            False
# 4       False              False                    True            False
#
#    isParkingSpaceIncludedInPrice  parkingSpacePrice
# 0                           True                0.0
# 1                          False                0.0
# 2                          False                0.0
# 3                          False                0.0
# 4                          False                0.0
#
# [5 rows x 25 columns]
