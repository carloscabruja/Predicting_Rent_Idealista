# %% [markdown]
# # Continue with the transformation process
# In this notebook we will make functions to transform the data into a prepared dataset to be processed by the model.

# %%
# Libraries used:
import pandas as pd
import numpy as np
import ast
import os
import warnings
from pyod.models.knn import KNN
import pickle

# config 
pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %% [markdown]
# The first step is to unify the data obtained and the corrupted data (if any).

# %%
def load_data():
    ''' 
    This function unify the raw data extrated with a corrupted if it exist any

    Returns:
    --------
    df: DataFrame with the raw data unified.
    '''
    # comprobate if the file exist
    if os.path.exists('../data/raw/data_raw.csv'):
        df = pd.read_csv('../data/raw/data_raw.csv')
    else:
        print('The file raw_data.csv does not exist')
    
    if os.path.exists('../data/raw/data_raw_corrupted.csv'):
        df_corrupted = pd.read_csv('../data/raw/data_raw_corrupted.csv')
        df = pd.concat([df, df_corrupted])
    else:
        print('There is no corrupted files')

    df.drop_duplicates(inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    return df

# %%
df = load_data()
df
# Out:
#       propertyCode                                          thumbnail  \
# 0         97942302  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 1         97956954  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 2         98200619  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3         98341195  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 4         98015046  https://img3.idealista.com/blur/WEB_LISTING/0/...
# ...            ...                                                ...
# 3017      98214599  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3018      98214582  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3019      98091690  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3020      98091689  https://img3.idealista.com/blur/WEB_LISTING/0/...
# 3021      91245678  https://img3.idealista.com/blur/WEB_LISTING/0/...
#
#       numPhotos   price  propertyType operation   size  exterior  rooms  \
# 0            23   850.0  countryHouse      rent  140.0     False      5
# 1            18   900.0        duplex      rent  100.0      True      3
# 2            26  1200.0          flat      rent  145.0      True      3
# 3            48  2700.0        chalet      rent  339.0     False      4
# 4            21  1800.0          flat      rent  103.0      True      3
# ...         ...     ...           ...       ...    ...       ...    ...
# 3017         34   995.0          flat      rent  104.0     False      3
# 3018         34  1085.0          flat      rent  109.0     False      3
# 3019         34  1045.0          flat      rent  103.0     False      3
# 3020         34  1040.0          flat      rent   83.0     False      2
# 3021         37  1100.0        chalet      rent  198.0     False      3
#
#       bathrooms                   address  province        municipality  \
# 0             2        Riba-Roja de Túria  València  Riba-Roja de Túria
# 1             3           Calle peñiscola  València             Manises
# 2             2            Calle de Conca  València            València
# 3             5       Avenida Buganvillas  València             Godella
# 4             2  Calle del Cura Planelles  València            València
# ...         ...                       ...       ...                 ...
# 3017          2     Plaça Num 137 Res Urb  València            València
# 3018          2     Plaça Num 137 Res Urb  València            València
# 3019          2     Plaça Num 137 Res Urb  València            València
# 3020          2     Plaça Num 137 Res Urb  València            València
# 3021          2                     Turis  València               Turis
#
#      country   latitude  longitude  showAddress  \
# 0         es  39.544071  -0.566219        False
# 1         es  39.499602  -0.474603        False
# 2         es  39.466220  -0.387735        False
# 3         es  39.529005  -0.425450        False
# 4         es  39.470266  -0.331696        False
# ...      ...        ...        ...          ...
# 3017      es  39.441000  -0.381710        False
# 3018      es  39.441400  -0.385010        False
# 3019      es  39.439600  -0.382210        False
# 3020      es  39.437800  -0.384510        False
# 3021      es  39.394838  -0.659338        False
#
#                                                  url  \
# 0       https://www.idealista.com/inmueble/97942302/
# 1       https://www.idealista.com/inmueble/97956954/
# 2       https://www.idealista.com/inmueble/98200619/
# 3       https://www.idealista.com/inmueble/98341195/
# 4       https://www.idealista.com/inmueble/98015046/
# ...                                              ...
# 3017  https://www.idealista.com/obra-nueva/98214599/
# 3018  https://www.idealista.com/obra-nueva/98214582/
# 3019  https://www.idealista.com/obra-nueva/98091690/
# 3020  https://www.idealista.com/obra-nueva/98091689/
# 3021    https://www.idealista.com/inmueble/91245678/
#
#                                             description  hasVideo  \
# 0     254-HORTA23- Bonita y luminosa vivienda en Rib...     False
# 1     Luminoso piso duplex de 3 habitaciones en mani...     False
# 2     GRAN VÍA INMOBILIARIA alquila piso en exclusiv...     False
# 3     Lion Capital Group le ofrece este espectacular...      True
# 4     Lion Capital Group le ofrece este precioso pis...      True
# ...                                                 ...       ...
# 3017                                                NaN     False
# 3018                                                NaN     False
# 3019                                                NaN     False
# 3020                                                NaN     False
# 3021  CERTIFICADO DE EFICIENCIA ENERGETICA E. Chalet...     False
#
#               status  newDevelopment  priceByArea  \
# 0               good           False          6.0
# 1               good           False          9.0
# 2               good           False          8.0
# 3               good           False          8.0
# 4               good           False         17.0
# ...              ...             ...          ...
# 3017  newdevelopment            True         10.0
# 3018  newdevelopment            True         10.0
# 3019  newdevelopment            True         10.0
# 3020  newdevelopment            True         13.0
# 3021            good           False          6.0
#
#                                            detailedType  \
# 0     {'typology': 'countryHouse', 'subTypology': 'c...
# 1         {'typology': 'flat', 'subTypology': 'duplex'}
# 2                                  {'typology': 'flat'}
# 3     {'typology': 'chalet', 'subTypology': 'terrace...
# 4                                  {'typology': 'flat'}
# ...                                                 ...
# 3017                               {'typology': 'flat'}
# 3018                               {'typology': 'flat'}
# 3019                               {'typology': 'flat'}
# 3020                               {'typology': 'flat'}
# 3021  {'typology': 'chalet', 'subTypology': 'indepen...
#
#                                          suggestedTexts  hasPlan  has3DTour  \
# 0     {'subtitle': 'Riba-Roja de Túria', 'title': 'C...    False      False
# 1     {'subtitle': 'Alameda Park, Manises', 'title':...    False      False
# 2     {'subtitle': 'Arrancapins, València', 'title':...    False      False
# 3     {'subtitle': 'Campolivar, Godella', 'title': '...     True      False
# 4     {'subtitle': 'El Cabanyal-El Canyamelar, Valèn...    False      False
# ...                                                 ...      ...        ...
# 3017  {'subtitle': 'Malilla, València', 'title': 'Pi...     True      False
# 3018  {'subtitle': 'Malilla, València', 'title': 'Pi...     True      False
# 3019  {'subtitle': 'Malilla, València', 'title': 'Pi...     True      False
# 3020  {'subtitle': 'Malilla, València', 'title': 'Pi...     True      False
# 3021  {'subtitle': 'Turis', 'title': 'Casa independi...    False      False
#
#       has360  hasStaging  topNewDevelopment  superTopHighlight  \
# 0      False       False              False              False
# 1      False       False              False              False
# 2      False       False              False              False
# 3      False       False              False              False
# 4      False       False              False              False
# ...      ...         ...                ...                ...
# 3017   False       False              False              False
# 3018   False       False              False              False
# 3019   False       False              False              False
# 3020   False       False              False              False
# 3021   False       False              False              False
#
#        externalReference floor          district hasLift  \
# 0                    NaN   NaN               NaN     NaN
# 1                     47     1      Alameda Park    True
# 2                  A587E     2         Extramurs    True
# 3               LCGV-155   NaN        Campolivar     NaN
# 4               LCGV-136    bj  Poblats Marítims    True
# ...                  ...   ...               ...     ...
# 3017  a1Q3W0000008s2sUAA     2   Quatre Carreres    True
# 3018  a1Q3W0000008s0ZUAQ     1   Quatre Carreres    True
# 3019  a1Q3W0000008s0eUAA    10   Quatre Carreres    True
# 3020  a1Q3W0000008s0bUAA    10   Quatre Carreres    True
# 3021               01081   NaN               NaN     NaN
#
#                                            parkingSpace  \
# 0                                                   NaN
# 1     {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 2                                                   NaN
# 3     {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 4                                                   NaN
# ...                                                 ...
# 3017                                                NaN
# 3018                                                NaN
# 3019                                                NaN
# 3020                                                NaN
# 3021  {'hasParkingSpace': True, 'isParkingSpaceInclu...
#
#                    neighborhood labels newDevelopmentFinished
# 0                           NaN    NaN                    NaN
# 1                           NaN    NaN                    NaN
# 2                   Arrancapins    NaN                    NaN
# 3                           NaN    NaN                    NaN
# 4     El Cabanyal-El Canyamelar    NaN                    NaN
# ...                         ...    ...                    ...
# 3017                    Malilla    NaN                  False
# 3018                    Malilla    NaN                  False
# 3019                    Malilla    NaN                  False
# 3020                    Malilla    NaN                  False
# 3021                        NaN    NaN                    NaN
#
# [3022 rows x 39 columns]

# %% [markdown]
# Filter by the columns we need to work with:

# %%
cols_needed = [
    'propertyCode', 
    'price', 
    'numPhotos', 
    'size',
    'floor',
    'rooms', 'bathrooms', 
    'latitude', 'longitude', 
    'propertyType',
    'status',
    'parkingSpace', 
    'exterior',
    'hasLift', 'hasPlan', 'has360', 'has3DTour', 'hasVideo',
    'newDevelopmentFinished',  
]

# drop the columns that are not needed
df = df[cols_needed]
df
# Out:
#       propertyCode   price  numPhotos   size floor  rooms  bathrooms  \
# 0         97942302   850.0         23  140.0   NaN      5          2
# 1         97956954   900.0         18  100.0     1      3          3
# 2         98200619  1200.0         26  145.0     2      3          2
# 3         98341195  2700.0         48  339.0   NaN      4          5
# 4         98015046  1800.0         21  103.0    bj      3          2
# ...            ...     ...        ...    ...   ...    ...        ...
# 3017      98214599   995.0         34  104.0     2      3          2
# 3018      98214582  1085.0         34  109.0     1      3          2
# 3019      98091690  1045.0         34  103.0    10      3          2
# 3020      98091689  1040.0         34   83.0    10      2          2
# 3021      91245678  1100.0         37  198.0   NaN      3          2
#
#        latitude  longitude  propertyType          status  \
# 0     39.544071  -0.566219  countryHouse            good
# 1     39.499602  -0.474603        duplex            good
# 2     39.466220  -0.387735          flat            good
# 3     39.529005  -0.425450        chalet            good
# 4     39.470266  -0.331696          flat            good
# ...         ...        ...           ...             ...
# 3017  39.441000  -0.381710          flat  newdevelopment
# 3018  39.441400  -0.385010          flat  newdevelopment
# 3019  39.439600  -0.382210          flat  newdevelopment
# 3020  39.437800  -0.384510          flat  newdevelopment
# 3021  39.394838  -0.659338        chalet            good
#
#                                            parkingSpace  exterior hasLift  \
# 0                                                   NaN     False     NaN
# 1     {'hasParkingSpace': True, 'isParkingSpaceInclu...      True    True
# 2                                                   NaN      True    True
# 3     {'hasParkingSpace': True, 'isParkingSpaceInclu...     False     NaN
# 4                                                   NaN      True    True
# ...                                                 ...       ...     ...
# 3017                                                NaN     False    True
# 3018                                                NaN     False    True
# 3019                                                NaN     False    True
# 3020                                                NaN     False    True
# 3021  {'hasParkingSpace': True, 'isParkingSpaceInclu...     False     NaN
#
#       hasPlan  has360  has3DTour  hasVideo newDevelopmentFinished
# 0       False   False      False     False                    NaN
# 1       False   False      False     False                    NaN
# 2       False   False      False     False                    NaN
# 3        True   False      False      True                    NaN
# 4       False   False      False      True                    NaN
# ...       ...     ...        ...       ...                    ...
# 3017     True   False      False     False                  False
# 3018     True   False      False     False                  False
# 3019     True   False      False     False                  False
# 3020     True   False      False     False                  False
# 3021    False   False      False     False                    NaN
#
# [3022 rows x 19 columns]

# %%
# Make propertyCode a index
df.set_index('propertyCode', inplace=True)

# %%
# See nan values
df.isnull().sum().sort_values(ascending=False)
# Out:
# newDevelopmentFinished    2987
# parkingSpace              2153
# floor                      371
# hasLift                    335
# hasVideo                     0
# has3DTour                    0
# has360                       0
# hasPlan                      0
# exterior                     0
# price                        0
# numPhotos                    0
# propertyType                 0
# longitude                    0
# latitude                     0
# bathrooms                    0
# rooms                        0
# size                         0
# status                       0
# dtype: int64

# %% [markdown]
# The nexts steps will we to create a functions that process all nan values and bad formatted data.

# %%
def process_status(df):
    '''
    This function process the status of the property.

    Parameters:
    -----------
    df: DataFrame with the raw data of status, newDevelopmentFinished.

    Returns:
    --------
    df: DataFrame with the raw data processed.
    '''

    # Create the columns that will replace the status column: renew and new_development.
    df['renew'] = df['status'].apply(lambda x: True if x == 'renew' else False)
    df['new_development'] = df['status'].apply(lambda x: True if x == 'newdevelopment' else False)

    # drop the status column
    df.drop('status', axis=1, inplace=True)

    # Same with newDevelopmentFinished
    df['isFinished'] = df['newDevelopmentFinished'].apply(lambda x: False if x == False else True)
    df.drop('newDevelopmentFinished', axis=1, inplace=True)

    return df

# %%
df = process_status(df)
df
# Out:
#                price  numPhotos   size floor  rooms  bathrooms   latitude  \
# propertyCode
# 97942302       850.0         23  140.0   NaN      5          2  39.544071
# 97956954       900.0         18  100.0     1      3          3  39.499602
# 98200619      1200.0         26  145.0     2      3          2  39.466220
# 98341195      2700.0         48  339.0   NaN      4          5  39.529005
# 98015046      1800.0         21  103.0    bj      3          2  39.470266
# ...              ...        ...    ...   ...    ...        ...        ...
# 98214599       995.0         34  104.0     2      3          2  39.441000
# 98214582      1085.0         34  109.0     1      3          2  39.441400
# 98091690      1045.0         34  103.0    10      3          2  39.439600
# 98091689      1040.0         34   83.0    10      2          2  39.437800
# 91245678      1100.0         37  198.0   NaN      3          2  39.394838
#
#               longitude  propertyType  \
# propertyCode
# 97942302      -0.566219  countryHouse
# 97956954      -0.474603        duplex
# 98200619      -0.387735          flat
# 98341195      -0.425450        chalet
# 98015046      -0.331696          flat
# ...                 ...           ...
# 98214599      -0.381710          flat
# 98214582      -0.385010          flat
# 98091690      -0.382210          flat
# 98091689      -0.384510          flat
# 91245678      -0.659338        chalet
#
#                                                    parkingSpace  exterior  \
# propertyCode
# 97942302                                                    NaN     False
# 97956954      {'hasParkingSpace': True, 'isParkingSpaceInclu...      True
# 98200619                                                    NaN      True
# 98341195      {'hasParkingSpace': True, 'isParkingSpaceInclu...     False
# 98015046                                                    NaN      True
# ...                                                         ...       ...
# 98214599                                                    NaN     False
# 98214582                                                    NaN     False
# 98091690                                                    NaN     False
# 98091689                                                    NaN     False
# 91245678      {'hasParkingSpace': True, 'isParkingSpaceInclu...     False
#
#              hasLift  hasPlan  has360  has3DTour  hasVideo  renew  \
# propertyCode
# 97942302         NaN    False   False      False     False  False
# 97956954        True    False   False      False     False  False
# 98200619        True    False   False      False     False  False
# 98341195         NaN     True   False      False      True  False
# 98015046        True    False   False      False      True  False
# ...              ...      ...     ...        ...       ...    ...
# 98214599        True     True   False      False     False  False
# 98214582        True     True   False      False     False  False
# 98091690        True     True   False      False     False  False
# 98091689        True     True   False      False     False  False
# 91245678         NaN    False   False      False     False  False
#
#               new_development  isFinished
# propertyCode
# 97942302                False        True
# 97956954                False        True
# 98200619                False        True
# 98341195                False        True
# 98015046                False        True
# ...                       ...         ...
# 98214599                 True       False
# 98214582                 True       False
# 98091690                 True       False
# 98091689                 True       False
# 91245678                False        True
#
# [3022 rows x 19 columns]

# %% [markdown]
# Same with parkingSpace

# %%
def process_parkingSpace(df):
    '''
    This function process the bad formatted parkingSpace

    Parameters:
    -----------
    df: DataFrame with the raw data of parkingSpace

    Returns:
    --------
    df: DataFrame with the raw data processed.
    '''
    # replace all the ' to " in the parkingSpace column
    df['parkingSpace'] = df['parkingSpace'].str.replace('\'', '"')

    # convert the string to a dictionary
    df['parkingSpace'] = df['parkingSpace'].apply(
        lambda x: ast.literal_eval(x) 
        if type(x) == str else x
        )

    # get the hasParkingSpace of the dict of the parkingSpace column
    df['hasParkingSpace'] = df['parkingSpace'].apply(
        lambda x: x['hasParkingSpace'] if type(x) == dict else False
        )

    # get isParkingSpaceIncludedInPrice 
    df['isParkingSpaceIncludedInPrice'] = df['parkingSpace'].apply(
        lambda x: x['isParkingSpaceIncludedInPrice'] if type(x) == dict else False
        )

    # get the parkingSpacePrice 
    df['parkingSpacePrice'] = df['parkingSpace'].apply(
        lambda x: x['parkingSpacePrice'] 
        if type(x) == dict and 'parkingSpacePrice' in x else 0
        )

    # drop the parkingSpace column
    df.drop(columns=['parkingSpace'], inplace=True)
    return df

# %%
df = process_parkingSpace(df)
df
# Out:
#                price  numPhotos   size floor  rooms  bathrooms   latitude  \
# propertyCode
# 97942302       850.0         23  140.0   NaN      5          2  39.544071
# 97956954       900.0         18  100.0     1      3          3  39.499602
# 98200619      1200.0         26  145.0     2      3          2  39.466220
# 98341195      2700.0         48  339.0   NaN      4          5  39.529005
# 98015046      1800.0         21  103.0    bj      3          2  39.470266
# ...              ...        ...    ...   ...    ...        ...        ...
# 98214599       995.0         34  104.0     2      3          2  39.441000
# 98214582      1085.0         34  109.0     1      3          2  39.441400
# 98091690      1045.0         34  103.0    10      3          2  39.439600
# 98091689      1040.0         34   83.0    10      2          2  39.437800
# 91245678      1100.0         37  198.0   NaN      3          2  39.394838
#
#               longitude  propertyType  exterior hasLift  hasPlan  has360  \
# propertyCode
# 97942302      -0.566219  countryHouse     False     NaN    False   False
# 97956954      -0.474603        duplex      True    True    False   False
# 98200619      -0.387735          flat      True    True    False   False
# 98341195      -0.425450        chalet     False     NaN     True   False
# 98015046      -0.331696          flat      True    True    False   False
# ...                 ...           ...       ...     ...      ...     ...
# 98214599      -0.381710          flat     False    True     True   False
# 98214582      -0.385010          flat     False    True     True   False
# 98091690      -0.382210          flat     False    True     True   False
# 98091689      -0.384510          flat     False    True     True   False
# 91245678      -0.659338        chalet     False     NaN    False   False
#
#               has3DTour  hasVideo  renew  new_development  isFinished  \
# propertyCode
# 97942302          False     False  False            False        True
# 97956954          False     False  False            False        True
# 98200619          False     False  False            False        True
# 98341195          False      True  False            False        True
# 98015046          False      True  False            False        True
# ...                 ...       ...    ...              ...         ...
# 98214599          False     False  False             True       False
# 98214582          False     False  False             True       False
# 98091690          False     False  False             True       False
# 98091689          False     False  False             True       False
# 91245678          False     False  False            False        True
#
#               hasParkingSpace  isParkingSpaceIncludedInPrice  \
# propertyCode
# 97942302                False                          False
# 97956954                 True                           True
# 98200619                False                          False
# 98341195                 True                           True
# 98015046                False                          False
# ...                       ...                            ...
# 98214599                False                          False
# 98214582                False                          False
# 98091690                False                          False
# 98091689                False                          False
# 91245678                 True                           True
#
#               parkingSpacePrice
# propertyCode
# 97942302                    0.0
# 97956954                    0.0
# 98200619                    0.0
# 98341195                    0.0
# 98015046                    0.0
# ...                         ...
# 98214599                    0.0
# 98214582                    0.0
# 98091690                    0.0
# 98091689                    0.0
# 91245678                    0.0
#
# [3022 rows x 21 columns]

# %%
def process_floor(df):
    ''' 
    This function process the bad formatted floor

    Parameters:
    -----------
    df: DataFrame with the raw data of floor

    Returns:
    --------
    df: DataFrame with the raw data processed.
    '''
    floor_nan = df[df['floor'].isnull()] # get the nan values
    property_type = floor_nan['propertyType'].value_counts().index.to_list()

    for i in property_type:
        # get the mode of the propertyType column
        mode = df['floor'][df['propertyType'] == i].mode()[0]
        # get the index of the rows with the propertyType i and the floor is null
        index = df[(df['propertyType'] == i) & (df['floor'].isnull())].index
        # replace the nan with the mode
        df.loc[index, 'floor'] = mode

    # where floor is 'bj' or 'en' put 0
    df.loc[df['floor'] == 'bj', 'floor'] = 0
    df.loc[df['floor'] == 'en', 'floor'] = 0

    # where floor is 'st' put 1
    df.loc[df['floor'] == 'st', 'floor'] = -1

    return df

# %%
df = process_floor(df)
df
# Out:
#                price  numPhotos   size floor  rooms  bathrooms   latitude  \
# propertyCode
# 97942302       850.0         23  140.0     0      5          2  39.544071
# 97956954       900.0         18  100.0     1      3          3  39.499602
# 98200619      1200.0         26  145.0     2      3          2  39.466220
# 98341195      2700.0         48  339.0     0      4          5  39.529005
# 98015046      1800.0         21  103.0     0      3          2  39.470266
# ...              ...        ...    ...   ...    ...        ...        ...
# 98214599       995.0         34  104.0     2      3          2  39.441000
# 98214582      1085.0         34  109.0     1      3          2  39.441400
# 98091690      1045.0         34  103.0    10      3          2  39.439600
# 98091689      1040.0         34   83.0    10      2          2  39.437800
# 91245678      1100.0         37  198.0     0      3          2  39.394838
#
#               longitude  propertyType  exterior hasLift  hasPlan  has360  \
# propertyCode
# 97942302      -0.566219  countryHouse     False     NaN    False   False
# 97956954      -0.474603        duplex      True    True    False   False
# 98200619      -0.387735          flat      True    True    False   False
# 98341195      -0.425450        chalet     False     NaN     True   False
# 98015046      -0.331696          flat      True    True    False   False
# ...                 ...           ...       ...     ...      ...     ...
# 98214599      -0.381710          flat     False    True     True   False
# 98214582      -0.385010          flat     False    True     True   False
# 98091690      -0.382210          flat     False    True     True   False
# 98091689      -0.384510          flat     False    True     True   False
# 91245678      -0.659338        chalet     False     NaN    False   False
#
#               has3DTour  hasVideo  renew  new_development  isFinished  \
# propertyCode
# 97942302          False     False  False            False        True
# 97956954          False     False  False            False        True
# 98200619          False     False  False            False        True
# 98341195          False      True  False            False        True
# 98015046          False      True  False            False        True
# ...                 ...       ...    ...              ...         ...
# 98214599          False     False  False             True       False
# 98214582          False     False  False             True       False
# 98091690          False     False  False             True       False
# 98091689          False     False  False             True       False
# 91245678          False     False  False            False        True
#
#               hasParkingSpace  isParkingSpaceIncludedInPrice  \
# propertyCode
# 97942302                False                          False
# 97956954                 True                           True
# 98200619                False                          False
# 98341195                 True                           True
# 98015046                False                          False
# ...                       ...                            ...
# 98214599                False                          False
# 98214582                False                          False
# 98091690                False                          False
# 98091689                False                          False
# 91245678                 True                           True
#
#               parkingSpacePrice
# propertyCode
# 97942302                    0.0
# 97956954                    0.0
# 98200619                    0.0
# 98341195                    0.0
# 98015046                    0.0
# ...                         ...
# 98214599                    0.0
# 98214582                    0.0
# 98091690                    0.0
# 98091689                    0.0
# 91245678                    0.0
#
# [3022 rows x 21 columns]

# %%
def process_hasLift(df):
    ''' 
    This function process all nan values of hasLift

    Parameters:
    -----------
    df: DataFrame with the raw data of hasLift

    Returns:
    --------
    df: DataFrame with the raw data processed.
    '''
    # get the index of the rows with the hasLift is null
    index = df[df['hasLift'].isnull()].index
    # replace the nan with False
    df.loc[index, 'hasLift'] = False
    
    return df

# %%
df = process_hasLift(df) 
df.isnull().sum().sort_values(ascending=False)
# Out:
# price                            0
# hasPlan                          0
# isParkingSpaceIncludedInPrice    0
# hasParkingSpace                  0
# isFinished                       0
# new_development                  0
# renew                            0
# hasVideo                         0
# has3DTour                        0
# has360                           0
# hasLift                          0
# numPhotos                        0
# exterior                         0
# propertyType                     0
# longitude                        0
# latitude                         0
# bathrooms                        0
# rooms                            0
# floor                            0
# size                             0
# parkingSpacePrice                0
# dtype: int64

# %% [markdown]
# Let's force-secure the type of the data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3022 entries, 97942302 to 91245678
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   price                          3022 non-null   float64
#  1   numPhotos                      3022 non-null   int64
#  2   size                           3022 non-null   float64
#  3   floor                          3022 non-null   object
#  4   rooms                          3022 non-null   int64
#  5   bathrooms                      3022 non-null   int64
#  6   latitude                       3022 non-null   float64
#  7   longitude                      3022 non-null   float64
#  8   propertyType                   3022 non-null   object
#  9   exterior                       3022 non-null   bool
#  10  hasLift                        3022 non-null   object
#  11  hasPlan                        3022 non-null   bool
#  12  has360                         3022 non-null   bool
#  13  has3DTour                      3022 non-null   bool
#  14  hasVideo                       3022 non-null   bool
#  15  renew                          3022 non-null   bool
#  16  new_development                3022 non-null   bool
#  17  isFinished                     3022 non-null   bool
#  18  hasParkingSpace                3022 non-null   bool
#  19  isParkingSpaceIncludedInPrice  3022 non-null   bool
#  20  parkingSpacePrice              3022 non-null   float64
# dtypes: bool(10), float64(5), int64(3), object(3)
# memory usage: 377.4+ KB

# %%
def retype_data(df):
    ''' 
    This function forcetype all columns of the dataset

    Parameters:
    -----------
    df: DataFrame with the raw data

    Returns:
    --------
    df: DataFrame with secure types.
    '''

    # int types
    df['numPhotos'] = df['numPhotos'].astype(int)
    df['floor'] = df['floor'].astype(int)
    df['rooms'] = df['rooms'].astype(int)
    df['bathrooms'] = df['bathrooms'].astype(int)

    # float types
    df['price'] = df['price'].astype(float)
    df['size'] = df['size'].astype(float)
    df['parkingSpacePrice'] = df['parkingSpacePrice'].astype(float)
    df['latitude'] = df['latitude'].astype(float)
    df['longitude'] = df['longitude'].astype(float)

    # boolean types
    df['exterior'] = df['exterior'].astype(bool)
    df['renew'] = df['renew'].astype(bool)
    df['new_development'] = df['new_development'].astype(bool)
    df['hasParkingSpace'] = df['hasParkingSpace'].astype(bool)
    df['isParkingSpaceIncludedInPrice'] = df['isParkingSpaceIncludedInPrice'].astype(bool)
    df['isFinished'] = df['isFinished'].astype(bool)
    df['hasLift'] = df['hasLift'].astype(bool)
    df['hasPlan'] = df['hasPlan'].astype(bool)
    df['has360'] = df['has360'].astype(bool)
    df['has3DTour'] = df['has3DTour'].astype(bool)
    df['hasVideo'] = df['hasVideo'].astype(bool)

    # object types
    df['propertyType'] = df['propertyType'].astype(str)

    order_of_cols = ['price', 'numPhotos', 'floor', 'rooms', 'bathrooms',
    'size', 'parkingSpacePrice', 'latitude', 'longitude', 'exterior', 'renew',
    'new_development', 'hasParkingSpace', 'isParkingSpaceIncludedInPrice',
    'isFinished', 'hasLift', 'hasPlan', 'has360', 'has3DTour', 'hasVideo',
    'propertyType']
    
    df = df[order_of_cols]
    return df

# %%
df = retype_data(df)
df.shape
# Out:
# (3022, 21)

# %% [markdown]
# Nows let's deal with the outliers.

# %%
def drop_outliers(df):
    '''
    This function drop the outliers of the dataset by KNN method

    Parameters:
    -----------
    df: DataFrame with the outliers

    Returns:
    --------
    df: DataFrame with the outliers dropped.
    '''
    num_cols = df.select_dtypes(include=['int64', 'float64']).columns
    
    clf = KNN()
    clf.fit(df[num_cols])
    y_pred = clf.predict(df[num_cols])

    print(f'The percentage of outliers is {100*sum(y_pred)/len(y_pred)}%')
    
    df = df[y_pred == 0]
    return df

# %%
df = drop_outliers(df) 
df.shape
# Out:
# The percentage of outliers is 8.669755129053607%
# (2760, 21)

# %% [markdown]
# At this point we automated the process of data cleaning, let's automate the transformation of address.

# %%
def clustering_address(df):
    '''
    This function create cluster from the latitude and longitude a append it to the dataset

    Parameters:
    -----------
    df: DataFrame with the latitude and longitude

    Returns:
    --------
    df: DataFrame with the latitude and longitude clustered.
    '''
    # load the clustering model
    cluster = pickle.load(open('../models/kmeans_clustering.pkl', 'rb'))
    # get the cluster of the latitude and longitude
    df['cluster'] = cluster.predict(df[['latitude', 'longitude']])

    # drop the latitude and longitude columns
    df.drop(columns=['latitude', 'longitude'], inplace=True)

    return df

# %%
df = clustering_address(df)
df.cluster.value_counts()
# Out:
# 0    2250
# 2     197
# 1     177
# 3     136
# Name: cluster, dtype: int64

# %%
df.sample(5)
# Out:
#                price  numPhotos  floor  rooms  bathrooms   size  \
# propertyCode
# 98254835      3500.0         25      0      5          3  350.0
# 97525641      2150.0         33      2      2          2   99.0
# 97019989       950.0         31      1      3          1   75.0
# 32771983       950.0          7      3      4          1   84.0
# 36291521       620.0         10      7      0          1   40.0
#
#               parkingSpacePrice  exterior  renew  new_development  \
# propertyCode
# 98254835                    0.0     False  False            False
# 97525641                    0.0      True  False            False
# 97019989                    0.0      True  False            False
# 32771983                    0.0      True  False            False
# 36291521                    0.0      True  False            False
#
#               hasParkingSpace  isParkingSpaceIncludedInPrice  isFinished  \
# propertyCode
# 98254835                 True                           True        True
# 97525641                False                          False        True
# 97019989                False                          False        True
# 32771983                False                          False        True
# 36291521                 True                           True        True
#
#               hasLift  hasPlan  has360  has3DTour  hasVideo propertyType  \
# propertyCode
# 98254835        False    False   False      False     False       chalet
# 97525641         True     True   False      False     False         flat
# 97019989         True    False   False      False     False         flat
# 32771983         True    False   False      False     False         flat
# 36291521         True    False   False      False     False       studio
#
#               cluster
# propertyCode
# 98254835            3
# 97525641            0
# 97019989            0
# 32771983            0
# 36291521            0

# %% [markdown]
# This looks like a good dataset to do feature engineering.
